# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('covid_19_indonesia_time_series_all.csv')
df.head()
# Out:
#         Date Location ISO Code    Location  New Cases  New Deaths  \
# 0   1/8/2020             ID-JI  Jawa Timur          9           3
# 1   1/9/2020             ID-JI  Jawa Timur          0           1
# 2  1/10/2020             ID-JI  Jawa Timur          0           1
# 3  1/11/2020             ID-JI  Jawa Timur          0           3
# 4  1/12/2020             ID-JI  Jawa Timur          0           3
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              1                 5            9             5
# 1             23               -24            9             6
# 2             14               -15            9             7
# 3              8               -11            9            10
# 4              1                -4            9            13
#
#    Total Recovered  ...  New Deaths per Million Total Deaths per Million  \
# 0               10  ...                    0.07                     0.12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16283 entries, 0 to 16282
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         16283 non-null  object
#  1   Location ISO Code            16283 non-null  object
#  2   Location                     16283 non-null  object
#  3   New Cases                    16283 non-null  int64
#  4   New Deaths                   16283 non-null  int64
#  5   New Recovered                16283 non-null  int64
#  6   New Active Cases             16283 non-null  int64
#  7   Total Cases                  16283 non-null  int64
#  8   Total Deaths                 16283 non-null  int64
#  9   Total Recovered              16283 non-null  int64
#  10  Total Active Cases           16283 non-null  int64
#  11  Location Level               16283 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %% [markdown]
# ### Cleaning Data

# %%
df_copy = df.copy()

# %%
df_clean = df_copy.drop(columns=['City or Regency', 'Name', 'Item', 'Kind', 'Hidden', 'Special Status'])

# %%
df_clean = df_clean.drop(columns=['Location ISO Code', 'Country', 'Continent', 'Location Level', 'Time Zone', 'Total Regencies', 'Total Cities', 'Total Districts', 'Total Rural Villages', 'Total Urban Villages', 'Area (km2)', 'Population Density', 'Longitude', 'Latitude'])

# %%
df_clean = df_clean.drop(columns=['New Cases per Million', 'Total Cases per Million', 'New Deaths per Million', 'Total Deaths per Million', 'New Active Cases', 'Total Active Cases', 'Location'])

# %%
df_clean = df_clean.dropna()

# %%
df_clean.duplicated().sum()
# Out:
# 0

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13059 entries, 1 to 16282
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         13059 non-null  object
#  1   New Cases                    13059 non-null  int64
#  2   New Deaths                   13059 non-null  int64
#  3   New Recovered                13059 non-null  int64
#  4   Total Cases                  13059 non-null  int64
#  5   Total Deaths                 13059 non-null  int64
#  6   Total Recovered              13059 non-null  int64
#  7   Province                     13059 non-null  object
#  8   Island                       13059 non-null  object
#  9   Population                   13059 non-null  int64
#  10  Case Fatality Rate           13059 non-null  object
#  11  Case Recovered Rate          13059 non-null  object
#  12  Growth Factor of New Cases   13059 non-null  float64
# ...

# %%
df_clean.head(10)
# Out:
#          Date  New Cases  New Deaths  New Recovered  Total Cases  \
# 1    1/9/2020          0           1             23            9
# 2   1/10/2020          0           1             14            9
# 3   1/11/2020          0           3              8            9
# 4   1/12/2020          0           3              1            9
# 5   1/13/2020          0           0              0            9
# 6   1/14/2020          0           0              0            9
# 7   1/15/2020          0           0              0            9
# 8   1/16/2020          0           0              0            9
# 9   1/17/2020          0           0              4            9
# 10  1/18/2020          0           0              8            9
#
#     Total Deaths  Total Recovered    Province Island  Population  \
# 1              6               33  Jawa Timur   Jawa    40479023
# 2              7               47  Jawa Timur   Jawa    40479023
# ...

# %%
df_clean['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
time_series = df_clean.loc[(df_clean['Date'] >= '1/1/2021')].reset_index(drop=True)
time_series
# Out:
#            Date  New Cases  New Deaths  New Recovered  Total Cases  \
# 0    2021-01-01          7           0             10         8753
# 1    2021-01-01        101           1             76        17694
# 2    2021-01-01        287          12            188        18441
# 3    2021-01-01         68           5             98         3671
# 4    2021-01-01       1956          20           1643       185691
# ...         ...        ...         ...            ...          ...
# 5416 2021-07-09        124           1              3        12447
# 5417 2021-07-09        278           9              9        17424
# 5418 2021-07-09        718          10            275        55675
# 5419 2021-07-09        341           6            221        31147
# 5420 2021-07-09        336           5            241        38040
#
#       Total Deaths  Total Recovered           Province         Island  \
# 0              358             7157               Aceh       Sumatera
# ...

# %% [markdown]
# ## Perkembangan Covid Periode 2021

# %%
time_series.describe()
# Out:
#               index     New Cases   New Deaths  New Recovered    Total Cases  \
# count   5421.000000   5421.000000  5421.000000    5421.000000    5421.000000
# mean   13059.099244    305.545471     7.354916     249.011253   50567.249400
# std     1874.014704    791.536790    17.695138     594.478865   86075.238053
# min     9823.000000      0.000000     0.000000       0.000000    1960.000000
# 25%    11421.000000     30.000000     0.000000      21.000000    9426.000000
# 50%    13057.000000     90.000000     2.000000      75.000000   17978.000000
# 75%    14689.000000    227.000000     6.000000     205.000000   43981.000000
# max    16282.000000  13112.000000   366.000000   15022.000000  636383.000000
#
#        Total Deaths  Total Recovered    Population  \
# count   5421.000000      5421.000000  5.421000e+03
# mean    1403.310828     44646.441616  8.664030e+06
# std     2432.940711     78144.025583  1.148721e+07
# min       27.000000      1206.000000  6.484070e+05
# ...

# %%
plt.figure(figsize=(20, 8))
plt.plot(time_series['Date'], time_series['New Cases'])
plt.plot(time_series['Date'], time_series['New Recovered'])
plt.plot(time_series['Date'], time_series['New Deaths'])
plt.ylabel('Jumlah Kasus')
plt.xlabel("Bulan")
plt.show()

# %% [markdown]
# ## Perkembangan kasus Covid-19 selama masa PPKM Darurat

# %% [markdown]
# ### Group data

# %%
df_group = df_clean.groupby(['Island','Province'])[['Total Cases', 'Total Deaths', 'Total Recovered', 'Population']].sum()
df_group['Total Positive'] = df_group['Total Cases'] - df_group['Total Recovered'] - df_group['Total Deaths']
df_group
# Out:
#                                           Total Cases  Total Deaths  \
# Island        Province
# Jawa          Banten                          7903752        219544
#               DKI Jakarta                    85445392       1504010
#               Daerah Istimewa Yogyakarta      7187415        178088
#               Jawa Barat                     51682704        700539
#               Jawa Tengah                    38201392       1756806
#               Jawa Timur                     34484105       2584515
# Kalimantan    Kalimantan Barat                1280487         12907
#               Kalimantan Selatan              6415286        216908
#               Kalimantan Tengah               3141261         76298
#               Kalimantan Timur               12919987        326780
#               Kalimantan Utara                1657376         24604
# Maluku        Maluku                          1388993         20739
# ...

# %%
df_group.to_csv('Covid-19-Indonesia.csv')

# %%
df_final = df_group.reset_index()
df_final
# Out:
#            Island                    Province  Total Cases  Total Deaths  \
# 0            Jawa                      Banten      7903752        219544
# 1            Jawa                 DKI Jakarta     85445392       1504010
# 2            Jawa  Daerah Istimewa Yogyakarta      7187415        178088
# 3            Jawa                  Jawa Barat     51682704        700539
# 4            Jawa                 Jawa Tengah     38201392       1756806
# 5            Jawa                  Jawa Timur     34484105       2584515
# 6      Kalimantan            Kalimantan Barat      1280487         12907
# 7      Kalimantan          Kalimantan Selatan      6415286        216908
# 8      Kalimantan           Kalimantan Tengah      3141261         76298
# 9      Kalimantan            Kalimantan Timur     12919987        326780
# 10     Kalimantan            Kalimantan Utara      1657376         24604
# 11         Maluku                      Maluku      1388993         20739
# ...

# %%
plt.figure(figsize=(20, 8))
plt.bar(df_final['Province'], df_final['Total Cases']);
plt.bar(df_final['Province'], df_final['Total Recovered']);
plt.bar(df_final['Province'], df_final['Total Deaths']);
plt.xticks(rotation=90);
